# %% [markdown]
# ### Start of Week 3 - Part 1

# %%
import pandas as pd
import requests
import numpy as np
print('Import Complete!')
# Out:
# Import Complete!

# %%
TorontoDA=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]
TorontoDA.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
TorontoRD = TorontoDA
#creating a backup Dataflow

# %%
TorontoRD['Borough'] = TorontoRD['Borough'].replace('Not assigned', np.nan)
TorontoRD = TorontoRD.dropna(axis=0, subset=['Borough'])
TorontoRD.head(8)
#Replacing Not assigned values in "Borough" column of the table with Nan and then dropping rows with none values
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Not assigned
# 10      M9A         Etobicoke  Islington Avenue

# %%
TorontoRD['Neighbourhood'] = TorontoRD['Neighbourhood'].replace('Not assigned', np.nan)
TorontoRD.Neighbourhood.fillna(TorontoRD.Borough,inplace=True)
TorontoRD.head(8)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Queen's Park
# 10      M9A         Etobicoke  Islington Avenue

# %%
TorontoRD= TorontoRD.groupby(by=['Postcode','Borough'],sort = False).agg(lambda x: ','.join(x))
TorontoRD.head(10)
# Out:
#                                              Neighbourhood
# Postcode Borough
# M3A      North York                              Parkwoods
# M4A      North York                       Victoria Village
# M5A      Downtown Toronto         Harbourfront,Regent Park
# M6A      North York        Lawrence Heights,Lawrence Manor
# M7A      Queen's Park                         Queen's Park
# M9A      Etobicoke                        Islington Avenue
# M1B      Scarborough                         Rouge,Malvern
# M3B      North York                        Don Mills North
# M4B      East York          Woodbine Gardens,Parkview Hill
# M5B      Downtown Toronto          Ryerson,Garden District

# %%
TorontoRD=TorontoRD.reset_index()
TorontoRD.head(10)
# Out:
#    index Postcode           Borough                    Neighbourhood
# 0      0      M3A        North York                        Parkwoods
# 1      1      M4A        North York                 Victoria Village
# 2      2      M5A  Downtown Toronto         Harbourfront,Regent Park
# 3      3      M6A        North York  Lawrence Heights,Lawrence Manor
# 4      4      M7A      Queen's Park                     Queen's Park
# 5      5      M9A         Etobicoke                 Islington Avenue
# 6      6      M1B       Scarborough                    Rouge,Malvern
# 7      7      M3B        North York                  Don Mills North
# 8      8      M4B         East York   Woodbine Gardens,Parkview Hill
# 9      9      M5B  Downtown Toronto          Ryerson,Garden District

# %%
[[TorontoRD]]
# Out:
# [[     index Postcode           Borough  \
#   0        0      M3A        North York
#   1        1      M4A        North York
#   2        2      M5A  Downtown Toronto
#   3        3      M6A        North York
#   4        4      M7A      Queen's Park
#   5        5      M9A         Etobicoke
#   6        6      M1B       Scarborough
#   7        7      M3B        North York
#   8        8      M4B         East York
#   9        9      M5B  Downtown Toronto
#   10      10      M6B        North York
#   11      11      M9B         Etobicoke
#   12      12      M1C       Scarborough
#   13      13      M3C        North York
#   14      14      M4C         East York
#   15      15      M5C  Downtown Toronto
#   16      16      M6C              York
#   17      17      M9C         Etobicoke
#   18      18      M1E       Scarborough
#   19      19      M4E      East Toronto
#   20      20      M5E  Downtown Toronto
#   21      21      M6E              York
# ...

# %%
Toronto_df=TorontoRD
Toronto_df.shape
# Out:
# (103, 4)
